# %%
 #!/usr/bin/env python
# -*- coding: utf-8 -*-
import sys
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import os
plt.style.use('seaborn-poster')

# %%
df = pd.read_csv("tiempos.csv")
df.groupby("p_archivos").mean().plot().set_ylabel("Tiempo de ejecución (ns)")
plt.show()
